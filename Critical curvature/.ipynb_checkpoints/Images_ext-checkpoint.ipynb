# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score, cross_val_predict
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score, root_mean_squared_error, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from hyperopt import tpe, Trials, hp, fmin, STATUS_OK
from functools import partial
from sklearn.neighbors import KNeighborsRegressor

# %%
with open ('Features_RDKit/rdkit_descs.pickle', 'rb') as inp:
    rdkit_descs = pickle.load(inp)

# %%
nonionic_descs = rdkit_descs['RDKIt_non_ionic']

# %%
target = pd.read_csv('Data/Data_non_ionic.csv')['Cc ']

# %%
X_train, X_test, y_train, y_test = train_test_split(nonionic_descs, target, random_state=0)

# %% [markdown]
# Images for nonionics

# %%
lr = Ridge(alpha = 98.77341099629008, solver = 'lsqr')

# %%
pipe = make_pipeline(StandardScaler(), lr)

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('ridge', Ridge(alpha=98.77341099629008, solver='lsqr'))])

# %%
train_predicted = pipe.predict(X_train)

# %%
test_predicted = pipe.predict(X_test)

# %%
plt.figure(figsize = (8, 8))
plt.plot(y_train, train_predicted, 'ro', label = 'Train values')
plt.plot(y_test, test_predicted, 'go', label = 'Test values')
plt.plot([target.min()-5, target.max()+5], [target.min()-5, target.max()+5])
plt.xlim([-25, 10])
plt.ylim([-25, 10])
plt.legend()
plt.xlabel('True values')
plt.ylabel('Predicted values')
plt.savefig('Ridge-nonionics.png')

# %%
pipe_svm = make_pipeline(StandardScaler(), SVR(C = 0.015082446203887703, coef0 = 0.5909033059574486, degree = 2, gamma = 'auto', kernel = 'linear'))

# %%
pipe_svm.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svr',
#                  SVR(C=0.015082446203887703, coef0=0.5909033059574486, degree=2,
#                      gamma='auto', kernel='linear'))])

# %%
train_predicted = pipe_svm.predict(X_train)
test_predicted = pipe_svm.predict(X_test)

# %%
plt.figure(figsize = (8, 8))
plt.plot(y_train, train_predicted, 'ro', label = 'Train values')
plt.plot(y_test, test_predicted, 'go', label = 'Test values')
plt.plot([target.min()-5, target.max()+5], [target.min()-5, target.max()+5])
plt.xlim([-25, 10])
plt.ylim([-25, 10])
plt.legend()
plt.xlabel('True values')
plt.ylabel('Predicted values')
plt.savefig('SVM-nonionics.png')
