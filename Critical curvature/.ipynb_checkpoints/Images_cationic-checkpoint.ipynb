# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score, cross_val_predict
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score, root_mean_squared_error, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from hyperopt import tpe, Trials, hp, fmin, STATUS_OK
from functools import partial
from sklearn.neighbors import KNeighborsRegressor

# %%
with open ('Features_PaDEL/padel_descks.pickle', 'rb') as inp:
    rdkit_descs = pickle.load(inp)

# %%
nonionic_descs = rdkit_descs['PaDEL_anionic']

# %%
target = pd.read_csv('Data/Data_anionic.csv')['Cc ']

# %%
X_train, X_test, y_train, y_test = train_test_split(nonionic_descs, target, random_state=0)

# %% [markdown]
# Images for anionic

# %%
pipe_lr = make_pipeline(StandardScaler(), Ridge(solver = 'saga', alpha = 69.95332303268256))

# %%
pipe_lr.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('ridge', Ridge(alpha=69.95332303268256, solver='saga'))])

# %%
train_predicted = pipe_lr.predict(X_train)
test_predicted = pipe_lr.predict(X_test)

# %%
plt.figure(figsize = (8, 8))
plt.plot(y_train, train_predicted, 'ro', label = 'Train values')
plt.plot(y_test, test_predicted, 'go', label = 'Test values')
plt.plot([target.min()-5, target.max()+5], [target.min()-5, target.max()+5])
plt.xlim([-6, 4])
plt.ylim([-6, 4])
plt.legend()
plt.xlabel('True values')
plt.ylabel('Predicted values')
plt.savefig('Ridge-anionics.png')

# %%
pipe_svm = make_pipeline(StandardScaler(), SVR(C =  7.152758833526424, coef0 = 2.537414014288427, degree = 3, gamma = 'auto',  kernel = 'rbf'  ))
pipe_svm.fit(X_train, y_train)

train_predicted = pipe_svm.predict(X_train)
test_predicted = pipe_svm.predict(X_test)

plt.figure(figsize = (8, 8))
plt.plot(y_train, train_predicted, 'ro', label = 'Train values')
plt.plot(y_test, test_predicted, 'go', label = 'Test values')
plt.plot([target.min()-5, target.max()+5], [target.min()-5, target.max()+5])
plt.xlim([-6, 4])
plt.ylim([-6, 4])
plt.legend()
plt.xlabel('True values')
plt.ylabel('Predicted values')
plt.savefig('SVM-anionics.png')
