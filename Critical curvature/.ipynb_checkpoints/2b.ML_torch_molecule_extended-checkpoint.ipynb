# %% [markdown]
# **Overview**
# This notebook describes Cc prediction with torch-molecule models. There are 9 DL models for properties predction (mostly, different types of GNNs). The structure of notebook resembles the one, employing shallow methods. First, we assess model performance and select the best one

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

from torch_molecule import GREAMolecularPredictor
from tqdm import tqdm

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score, cross_val_predict
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score, root_mean_squared_error, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from hyperopt import tpe, Trials, hp, fmin, STATUS_OK
from functools import partial
from sklearn.neighbors import KNeighborsRegressor

# %%
from torch_molecule import GREAMolecularPredictor, BFGNNMolecularPredictor, SGIRMolecularPredictor, GRINMolecularPredictor, DIRMolecularPredictor, SSRMolecularPredictor, IRMMolecularPredictor, RPGNNMolecularPredictor, GNNMolecularPredictor, LSTMMolecularPredictor

# %% [markdown]
# We import dataset, containing Cc values vs SMILES of molecules

# %%
data_extended = pd.read_csv('Data_extended.csv', usecols=[1,2])

# %%
def calculate_to_score(estimator, dataset):
    train, test = train_test_split(dataset, random_state=0, train_size=0.75)
    train, val = train_test_split(train, random_state=0, train_size=0.12)
    
    est = estimator
    best_estimator  = est.autofit(X_train = list(train['SMILES']),
                                        y_train = list(train['Cc ']),
                                        X_val = list(val['SMILES']),
                                        y_val = list(val['Cc ']), n_trials = 10)    
    
    predictions= best_estimator.predict(list(test['SMILES']))['prediction']
    predictions_train = best_estimator.predict(list(train['SMILES']))['prediction']
    scores['Estimator'].append(est.model_name)
    scores['R2_test'].append(r2_score(test['Cc '], predictions))
    scores['R2_train'].append(r2_score(train['Cc '], predictions_train))
        
    scores['RMSE_test'].append(root_mean_squared_error(test['Cc '], predictions))
    scores['RMSE_train'].append(root_mean_squared_error(train['Cc '], predictions_train))

        
    scores['MAE_test'].append(mean_absolute_error(test['Cc '], predictions))
    scores['MAE_train'].append(mean_absolute_error(train['Cc '], predictions_train))

# %%
scores = { 'Estimator': [],  'R2_test':[], 'RMSE_test':[], 'MAE_test':[], 'R2_train':[], 'RMSE_train':[], 'MAE_train':[] }
trained_models = {}

# %% [markdown]
# Let's initialize scores dictionary and test function with Logistic Regression

# %%
models = [GREAMolecularPredictor, BFGNNMolecularPredictor, GRINMolecularPredictor, DIRMolecularPredictor, SSRMolecularPredictor, IRMMolecularPredictor, RPGNNMolecularPredictor,GNNMolecularPredictor]

# %%
for model in tqdm(models):
    calculate_to_score(model(device = 'cuda:0'), dataset = data_extended)
# Out:
# 100%|██████████| 8/8 [11:32<00:00, 86.57s/it]

# %%
pd.DataFrame(scores)
# Out:
#                  Estimator   R2_test  RMSE_test  MAE_test  R2_train  \
# 0   GREAMolecularPredictor -0.443069   1.618589  1.507614  0.420387
# 1  BFGNNMolecularPredictor -1.124437   1.963880  1.747761 -0.074599
# 2   GRINMolecularPredictor -0.392528   1.589992  1.354140  0.563543
# 3    DIRMolecularPredictor -0.051602   1.381715  1.213244  0.082620
# 4    SSRMolecularPredictor  0.502456   0.950405  0.764108  0.508150
# 5    IRMMolecularPredictor -0.808238   1.811844  1.659154  0.707473
# 6  RPGNNMolecularPredictor  0.043698   1.317621  0.958176  0.541127
# 7    GNNMolecularPredictor -1.290583   2.039229  1.890681  0.178049
#
#    RMSE_train  MAE_train
# 0    1.408448   1.389869
# 1    1.917763   1.589773
# 2    1.222200   1.210728
# 3    1.771929   1.766716
# 4    1.297442   1.280207
# 5    1.000587   0.725789
# 6    1.253193   1.083618
# 7    1.677238   1.476816

# %% [markdown]
# Two models:
# 1. SGIRMolecular predictor
# 2. LSTMMolecular predictor
#
# Must be done and loaded to scores manually. First we start with SGIRMolecular predictor, which requires the use of unlabelled SMILES

# %%
sgir = SGIRMolecularPredictor()
train, test = train_test_split(data_extended, random_state=0, train_size=0.75)
val, unlb = train_test_split(data_extended, random_state=0, train_size=0.5)

# %%
sgir.autofit(X_train = list(train['SMILES']),y_train = list(train['Cc ']),
             X_val = list(val['SMILES']),y_val  =list(val['Cc ']), X_unlbl = list(unlb['SMILES']))
# Out:
# SGIRMolecularPredictor(device=device(type='cuda', index=0), model_name='SGIRMolecularPredictor', model_class=<class 'torch_molecule.predictor.grea.model.GREA'>, model=GREA(
#   (graph_encoder): GNN_node(
#     (atom_encoder): AtomEncoder(
#       (atom_embedding_list): ModuleList(
#         (0): Embedding(120, 433, max_norm=1)
#         (1): Embedding(5, 433, max_norm=1)
#         (2-3): 2 x Embedding(12, 433, max_norm=1)
#         (4): Embedding(10, 433, max_norm=1)
#         (5-6): 2 x Embedding(6, 433, max_norm=1)
#         (7-8): 2 x Embedding(2, 433, max_norm=1)
#       )
#     )
#     (bond_encoder): BondEncoder(
#       (bond_embedding_list): ModuleList(
#         (0): Embedding(5, 433, max_norm=1)
#         (1): Embedding(6, 433, max_norm=1)
#         (2): Embedding(2, 433, max_norm=1)
#       )
#     )
#     (convs): ModuleList(
#       (0-6): 7 x GCNConv()
#     )
#     (batch_norms): ModuleList(
#       (0-6): 7 x GraphNorm(433)
#     )
#   )
#   (separator): Separator(
#     (rationale_encoder): GNN_node(
#       (atom_encoder): AtomEncoder(
#         (atom_embedding_list): ModuleList(
#           (0): Embedding(120, 433, max_norm=1)
#           (1): Embedding(5, 433, max_norm=1)
#           (2-3): 2 x Embedding(12, 433, max_norm=1)
#           (4): Embedding(10, 433, max_norm=1)
#           (5-6): 2 x Embedding(6, 433, max_norm=1)
#           (7-8): 2 x Embedding(2, 433, max_norm=1)
#         )
#       )
#       (bond_encoder): BondEncoder(
#         (bond_embedding_list): ModuleList(
#           (0): Embedding(5, 433, max_norm=1)
#           (1): Embedding(6, 433, max_norm=1)
#           (2): Embedding(2, 433, max_norm=1)
#         )
#       )
#       (convs): ModuleList(
#         (0-1): 2 x GCNConv()
#       )
#       (batch_norms): ModuleList(
#         (0-1): 2 x BatchNorm1d(433, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (gate_nn): Sequential(
#       (0): Linear(in_features=433, out_features=866, bias=True)
#       (1): BatchNorm1d(866, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.5, inplace=False)
#       (4): Linear(in_features=866, out_features=1, bias=True)
#     )
#   )
#   (predictor): MLP(
#     (fc1): Linear(in_features=433, out_features=866, bias=True)
#     (bn1): BatchNorm1d(866, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act
 0.7049448490142822, 0.6810537576675415, 0.46026456356048584, 0.695956826210022, 0.4676043391227722, 0.6259679198265076, 0.4513454735279083, 0.6100077629089355, 0.4320296347141266, 0.6143701076507568, 0.5388821363449097, 0.48822176456451416, 0.45675981044769287, 0.47988536953926086, 0.4537261426448822, 0.43638235330581665, 0.35089683532714844, 0.40370649099349976, 0.34593528509140015, 0.3706745207309723, 0.413402259349823, 0.33856260776519775, 0.5072517395019531, 0.3704736530780792, 0.48072874546051025, 0.35665082931518555, 0.3998197317123413, 0.46086233854293823, 0.3600582182407379, 0.48649221658706665, 0.3284340500831604, 0.42083778977 ...

# %%
predictions= sgir.predict(list(test['SMILES']))['prediction']
predictions_train = sgir.predict(list(train['SMILES']))['prediction']

scores['Estimator'].append(sgir.model_name)
scores['R2_test'].append(r2_score(test['Cc '], predictions))
scores['R2_train'].append(r2_score(train['Cc '], predictions_train))
        
scores['RMSE_test'].append(root_mean_squared_error(test['Cc '], predictions))
scores['RMSE_train'].append(root_mean_squared_error(train['Cc '], predictions_train))

        
scores['MAE_test'].append(mean_absolute_error(test['Cc '], predictions))
scores['MAE_train'].append(mean_absolute_error(train['Cc '], predictions_train))

# %% [markdown]
# Then we perform the same operations with LSTM predictor, which requires the use of target inout as Numpy array, not list

# %%
train, test = train_test_split(data_extended, random_state=0, train_size=0.75)
val, test = train_test_split(test, random_state=0, train_size=0.5)

# %%
lstm = LSTMMolecularPredictor()

# %%
lstm.autofit(X_train = list(train['SMILES']),
             y_train = np.array(train['Cc ']),
             X_val = list(val['SMILES']),
             y_val = np.array(val['Cc ']))
# Out:
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# ...
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([22])) that is different to the input size (torch.Size([22, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# LSTMMolecularPredictor(device=device(type='cuda', index=0), model_name='LSTMMolecularPredictor', model_class=<class 'torch_molecule.predictor.lstm.model.LSTM'>, model=LSTM(
#   (embedding): Embedding(54, 9)
#   (lstm1): LSTM(9, 108, batch_first=True, bidirectional=True)
#   (lstm2): LSTM(216, 108, batch_first=True, bidirectional=True)
#   (timedist_dense): Linear(in_features=216, out_features=54, bias=True)
#   (relu): ReLU()
#   (fc): Linear(in_features=10800, out_features=1, bias=True)
# ), is_fitted_=True, num_task=1, task_type='regression', input_dim=54, output_dim=9, LSTMunits=108, max_input_len=200, batch_size=128, epochs=500, loss_criterion=MSELoss(), evaluate_criterion=<function mean_absolute_error at 0x000001E0C1DC63E0>, evaluate_higher_better=False, learning_rate=0.00015160917467918527, weight_decay=0.00020795924942380875, patience=50, use_lr_scheduler=False, scheduler_factor=0.22606606177427208, scheduler_patience=5, verbose=False, fitting_loss=[3.339235305786133, 3.210261583328247, 3.0823075771331787, 2.950515031814575, 2.811858654022217, 2.6650748252868652, 2.5101282596588135, 2.3478567600250244, 2.1798837184906006, 2.008695125579834, 1.8372032642364502, 1.6694220304489136, 1.5102750062942505, 1.365797996520996, 1.243167757987976, 1.1503520011901855, 1.0951218605041504, 1.082872986793518, 1.11236572265625, 1.1695610284805298, 1.2289561033248901, 1.2675381898880005, 1.2761379480361938, 1.258219838142395, 1.2233526706695557, 1.1821924448013306, 1.143455982208252, 1.1124855279922485, 1.09157395362854, 1.0805468559265137, 1.077781081199646, 1.0809215307235718, 1.0874691009521484, 1.0952064990997314, 1.1024196147918701, 1.1079500913619995, 1.1111420392990112, 1.111828327178955, 1.1101020574569702, 1.1064001321792603, 1.1012663841247559, 1.0953571796417236, 1.0893720388412476, 1.0839358568191528, 1.079565405845642, 1.0765904188156128, 1.0751336812973022, 1.0750856399536133, 1.076136827468872, 1.077812671661377, 1.0795825719833374, 1.080992579460144, 1.0817406177520752, 1.0817197561264038, 1.0809993743896484, 1.0797749757766724, 1.0783106088638306, 1.0768499374389648, 1.0756161212921143, 1.0747385025024414, 1.0742449760437012, 1.0741095542907715, 1.0742515325546265, 1.0745632648468018, 1.0749262571334839, 1.075242519378662, 1.0754406452178955, 1.0754863023757935, 1.0753757953643799, 1.075139045715332, 1.0748196840286255, 1.0744789838790894], fitting_epoch=20)

# %%
predictions= lstm.predict(list(test['SMILES']))['prediction']
predictions_train = lstm.predict(list(train['SMILES']))['prediction']

scores['Estimator'].append(lstm.model_name)
scores['R2_test'].append(r2_score(test['Cc '], predictions))
scores['R2_train'].append(r2_score(train['Cc '], predictions_train))
        
scores['RMSE_test'].append(root_mean_squared_error(test['Cc '], predictions))
scores['RMSE_train'].append(root_mean_squared_error(train['Cc '], predictions_train))

        
scores['MAE_test'].append(mean_absolute_error(test['Cc '], predictions))
scores['MAE_train'].append(mean_absolute_error(train['Cc '], predictions_train))

# %%
pd.DataFrame(scores)
# Out:
#                  Estimator   R2_test  RMSE_test  MAE_test  R2_train  \
# 0   GREAMolecularPredictor -0.443069   1.618589  1.507614  0.420387
# 1  BFGNNMolecularPredictor -1.124437   1.963880  1.747761 -0.074599
# 2   GRINMolecularPredictor -0.392528   1.589992  1.354140  0.563543
# 3    DIRMolecularPredictor -0.051602   1.381715  1.213244  0.082620
# 4    SSRMolecularPredictor  0.502456   0.950405  0.764108  0.508150
# 5    IRMMolecularPredictor -0.808238   1.811844  1.659154  0.707473
# 6  RPGNNMolecularPredictor  0.043698   1.317621  0.958176  0.541127
# 7    GNNMolecularPredictor -1.290583   2.039229  1.890681  0.178049
# 8   SGIRMolecularPredictor  0.620045   0.830537  0.650916  0.990796
# 9   LSTMMolecularPredictor -0.111342   1.312030  1.273870  0.008844
#
#    RMSE_train  MAE_train
# 0    1.408448   1.389869
# 1    1.917763   1.589773
# 2    1.222200   1.210728
# 3    1.771929   1.766716
# 4    1.297442   1.280207
# 5    1.000587   0.725789
# 6    1.253193   1.083618
# 7    1.677238   1.476816
# 8    0.099397   0.066754
# 9    1.031482   0.843633

# %%
with open('scores_extended_torch.pickle', 'wb') as output:
    pickle.dump(scores, output)

# %% [markdown]
# As we can see, SGIR model have the best generalization performace (highest R2, lowest RMSE - about 0.36 lower, than for the best shallow model). We will perform hyperparameter tuning for SGIR using *hyperopt* package

# %%
def objective(params, X):
    SGIR = SGIRMolecularPredictor(num_layer = params['num_layer'], hidden_size = params['hidden_size'], gnn_type = params['gnn_type'], graph_pooling = params['graph_pooling'], weight_decay = params['weight_decay'], use_lr_scheduler = params['use_lr_scheduler'])
    kf = KFold(n_splits = 5)
    cv_rmse_results = []
    cv_mae_results = []
    cv_r2_results = []
    
    for train_unlb_indices, test_indices in kf.split(X):
        
        train_indices, unlbl_indices = train_test_split(train_unlb_indices, random_state = 0, train_size=0.8)
        
        X_train = X.iloc[train_indices, :]['SMILES']
        y_train = X.iloc[train_indices, :]['Cc ']
        X_unlbl  = X.iloc[unlbl_indices, :]['SMILES']

        

        X_test = X.iloc[test_indices, :]['SMILES']
        y_test = X.iloc[test_indices, :]['Cc ']
        
        sgir.fit(X_train = list(X_train), y_train = list(y_train), X_unlbl = list(X_unlbl))

        predictions = sgir.predict(list(X_test))['prediction']
        
        cv_rmse_results.append(root_mean_squared_error(y_test, predictions))
        cv_mae_results.append(mean_absolute_error(y_test, predictions))
        cv_r2_results.append(r2_score(y_test, predictions))

    return {'loss':np.mean(cv_rmse_results), 'status':STATUS_OK, 'model':sgir, 'r2':-np.mean(cv_r2_results), 'mae':-np.mean(cv_mae_results)}

# %%
trials = Trials()

# %%
param_grid = {'num_layer': hp.randint('num_layer', 3,7),
              'hidden_size':hp.randint('hidden_size', 200, 400),
              'gnn_type': hp.choice('gnn_type', ["gin-virtual", "gcn-virtual", "gin", "gcn"]),
              'graph_pooling':hp.choice('graph_pooling', ['mean', 'sum', 'max']),
              'weight_decay':hp.loguniform('weight_decay', -13, -4),
              'use_lr_scheduler':hp.choice('use_lr_scheduler', [True, False])}

# %%
best = fmin(partial(objective, X = data_extended), space = param_grid, trials = trials, algo = tpe.suggest, max_evals=  25)
# Out:
#   0%|          | 0/25 [00:00<?, ?trial/s, best loss=?]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#   4%|▍         | 1/25 [01:30<36:18, 90.77s/trial, best loss: 1.2229548140726607]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#   8%|▊         | 2/25 [02:51<32:26, 84.63s/trial, best loss: 1.2229548140726607]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  12%|█▏        | 3/25 [04:14<30:48, 84.03s/trial, best loss: 1.2229548140726607]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  16%|█▌        | 4/25 [05:25<27:40, 79.05s/trial, best loss: 1.2164584979383617]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  20%|██        | 5/25 [06:50<26:58, 80.94s/trial, best loss: 1.2164584979383617]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  24%|██▍       | 6/25 [08:19<26:35, 83.96s/trial, best loss: 1.2164584979383617]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  28%|██▊       | 7/25 [09:38<24:39, 82.19s/trial, best loss: 1.2144319809932482]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  32%|███▏      | 8/25 [11:01<23:21, 82.42s/trial, best loss: 1.2144319809932482]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  36%|███▌      | 9/25 [12:23<21:56, 82.27s/trial, best loss: 1.2144319809932482]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  40%|████      | 10/25 [13:34<19:41, 78.79s/trial, best loss: 1.2144319809932482]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  44%|████▍     | 11/25 [15:07<19:26, 83.31s/trial, best loss: 1.161841706332999]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  48%|████▊     | 12/25 [16:38<18:30, 85.39s/trial, best loss: 1.161841706332999]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  52%|█████▏    | 13/25 [18:03<17:05, 85.47s/trial, best loss: 1.161841706332999]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  56%|█████▌    | 14/25 [19:27<15:36, 85.11s/trial, best loss: 1.161841706332999]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  60%|██████    | 15/25 [20:52<14:07, 84.79s/trial, best loss: 1.161841706332999]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  64%|██████▍   | 16/25 [22:37<13:40, 91.13s/trial, best loss: 1.161841706332999]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  68%|██████▊   | 17/25 [24:12<12:18, 92.27s/trial, best loss: 1.161841706332999]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  72%|███████▏  | 18/25 [25:32<10:19, 88.51s/trial, best loss: 1.161841706332999]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  76%|███████▌  | 19/25 [26:51<08:33, 85.60s/trial, best loss: 1.161841706332999]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  80%|████████  | 20/25 [28:12<07:01, 84.24s/trial, best loss: 1.161841706332999]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  84%|████████▍ | 21/25 [29:37<05:38, 84.55s/trial, best loss: 1.161841706332999]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  88%|████████▊ | 22/25 [31:09<04:20, 86.77s/trial, best loss: 1.161841706332999]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  92%|█████████▏| 23/25 [32:30<02:49, 84.99s/trial, best loss: 1.161841706332999]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  96%|█████████▌| 24/25 [33:51<01:23, 83.69s/trial, best loss: 1.161841706332999]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# 100%|██████████| 25/25 [35:21<00:00, 84.86s/trial, best loss: 1.161841706332999]

# %%
print(best)
# Out:
# {'gnn_type': 3, 'graph_pooling': 2, 'hidden_size': 218, 'num_layer': 3, 'use_lr_scheduler': 1, 'weight_decay': 0.0002076634657605131}

# %% [markdown]
# Let's finally fit the best estimator and plot predicted values vs true ones

# %%
train, test = train_test_split(data_extended, random_state=0)
train, unlbl = train_test_split(train, random_state=0, train_size=0.9)

# %%
sgir = SGIRMolecularPredictor(gnn_type='gcn', graph_pooling='max', hidden_size=218, num_layer=3, use_lr_scheduler=False, weight_decay=0.0002076634657605131)
sgir.fit(X_train = list(train['SMILES']),
               y_train=list(train['Cc ']),
               X_unlbl = list(unlbl['SMILES']))
# Out:
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# SGIRMolecularPredictor(device=device(type='cuda', index=0), model_name='SGIRMolecularPredictor', model_class=<class 'torch_molecule.predictor.grea.model.GREA'>, model=GREA(
#   (graph_encoder): GNN_node(
#     (atom_encoder): AtomEncoder(
#       (atom_embedding_list): ModuleList(
#         (0): Embedding(120, 218, max_norm=1)
#         (1): Embedding(5, 218, max_norm=1)
#         (2-3): 2 x Embedding(12, 218, max_norm=1)
#         (4): Embedding(10, 218, max_norm=1)
#         (5-6): 2 x Embedding(6, 218, max_norm=1)
#         (7-8): 2 x Embedding(2, 218, max_norm=1)
#       )
#     )
#     (bond_encoder): BondEncoder(
#       (bond_embedding_list): ModuleList(
#         (0): Embedding(5, 218, max_norm=1)
#         (1): Embedding(6, 218, max_norm=1)
#         (2): Embedding(2, 218, max_norm=1)
#       )
#     )
#     (convs): ModuleList(
#       (0-2): 3 x GCNConv()
#     )
#     (batch_norms): ModuleList(
#       (0-2): 3 x BatchNorm1d(218, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (separator): Separator(
#     (rationale_encoder): GNN_node(
#       (atom_encoder): AtomEncoder(
#         (atom_embedding_list): ModuleList(
#           (0): Embedding(120, 218, max_norm=1)
#           (1): Embedding(5, 218, max_norm=1)
#           (2-3): 2 x Embedding(12, 218, max_norm=1)
#           (4): Embedding(10, 218, max_norm=1)
#           (5-6): 2 x Embedding(6, 218, max_norm=1)
#           (7-8): 2 x Embedding(2, 218, max_norm=1)
#         )
#       )
#       (bond_encoder): BondEncoder(
#         (bond_embedding_list): ModuleList(
#           (0): Embedding(5, 218, max_norm=1)
#           (1): Embedding(6, 218, max_norm=1)
#           (2): Embedding(2, 218, max_norm=1)
#         )
#       )
#       (convs): ModuleList(
#         (0-1): 2 x GCNConv()
#       )
#       (batch_norms): ModuleList(
#         (0-1): 2 x BatchNorm1d(218, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (gate_nn): Sequential(
#       (0): Linear(in_features=218, out_features=436, bias=True)
#       (1): BatchNorm1d(436, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.5, inplace=False)
#       (4): Linear(in_features=436, out_features=1, bias=True)
#     )
#   )
#   (predictor): MLP(
#     (fc1): Linear(in_features=1409, out_features=436, bias=True)
#     (bn1): BatchNorm1d(436, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act
.0416585206985474, 1.0253173112869263, 1.3357361555099487, 1.2425955533981323, 1.160121202468872, 1.0053296089172363, 0.9770745038986206, 1.0207269191741943, 1.1914308071136475, 1.7102667093276978, 1.0273244380950928, 2.3510477542877197, 1.0715527534484863, 2.6205930709838867, 2.4951655864715576, 1.1438710689544678, 1.9561326503753662, 1.1351814270019531, 1.632176399230957, 1.0500373840332031, 1.9854587316513062, 1.099104881286621, 2.0114855766296387, 1.811560034751892, 1.2551823854446411, 1.7159440517425537, 1.1226117610931396, 1.4930473566055298, 1.2555651664733887, 1.2800731658935547, 1.3309489488601685, 1.1507487297058105, 1.2438853979110718, 1.09279465675354, 1.2792161703109741, 1.1350306272506714, 1.2924973964691162, 1.2698581218719482, 1.1304433345794678, 1.1838632822036743, 1.1756598949432373, 1.1557670831680298, 1.1361573934555054, 1.0624382495880127, 1.0902962684631348, 0.9955269694328308, 0.992058515548706, 1.0087373256 ...

# %%
sgir = SGIRMolecularPredictor(device = 'cuda:0')
sgir.autofit(X_train = list(train['SMILES']),
               y_train=list(train['Cc ']),
               X_unlbl = list(unlbl['SMILES']))
# Out:
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# SGIRMolecularPredictor(device=device(type='cuda', index=0), model_name='SGIRMolecularPredictor', model_class=<class 'torch_molecule.predictor.grea.model.GREA'>, model=GREA(
#   (graph_encoder): GNN_node(
#     (atom_encoder): AtomEncoder(
#       (atom_embedding_list): ModuleList(
#         (0): Embedding(120, 302, max_norm=1)
#         (1): Embedding(5, 302, max_norm=1)
#         (2-3): 2 x Embedding(12, 302, max_norm=1)
#         (4): Embedding(10, 302, max_norm=1)
#         (5-6): 2 x Embedding(6, 302, max_norm=1)
#         (7-8): 2 x Embedding(2, 302, max_norm=1)
#       )
#     )
#     (bond_encoder): BondEncoder(
#       (bond_embedding_list): ModuleList(
#         (0): Embedding(5, 302, max_norm=1)
#         (1): Embedding(6, 302, max_norm=1)
#         (2): Embedding(2, 302, max_norm=1)
#       )
#     )
#     (convs): ModuleList(
#       (0-1): 2 x GCNConv()
#     )
#     (batch_norms): ModuleList(
#       (0-1): 2 x GraphNorm(302)
#     )
#   )
#   (separator): Separator(
#     (rationale_encoder): GNN_node(
#       (atom_encoder): AtomEncoder(
#         (atom_embedding_list): ModuleList(
#           (0): Embedding(120, 302, max_norm=1)
#           (1): Embedding(5, 302, max_norm=1)
#           (2-3): 2 x Embedding(12, 302, max_norm=1)
#           (4): Embedding(10, 302, max_norm=1)
#           (5-6): 2 x Embedding(6, 302, max_norm=1)
#           (7-8): 2 x Embedding(2, 302, max_norm=1)
#         )
#       )
#       (bond_encoder): BondEncoder(
#         (bond_embedding_list): ModuleList(
#           (0): Embedding(5, 302, max_norm=1)
#           (1): Embedding(6, 302, max_norm=1)
#           (2): Embedding(2, 302, max_norm=1)
#         )
#       )
#       (convs): ModuleList(
#         (0-1): 2 x GCNConv()
#       )
#       (batch_norms): ModuleList(
#         (0-1): 2 x BatchNorm1d(302, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (gate_nn): Sequential(
#       (0): Linear(in_features=302, out_features=604, bias=True)
#       (1): BatchNorm1d(604, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.5, inplace=False)
#       (4): Linear(in_features=604, out_features=1, bias=True)
#     )
#   )
#   (predictor): MLP(
#     (fc1): Linear(in_features=1326, out_features=604, bias=True)
#     (bn1): BatchNorm1d(604, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act
647850037, 0.7143723368644714, 0.730903148651123, 0.6583210825920105, 0.6721154451370239, 0.6957062482833862, 0.6687943935394287, 0.6402420401573181, 0.6456785798072815, 0.6417504549026489, 0.6439586281776428, 0.6755788326263428, 0.6593430042266846, 0.6479390263557434, 0.7017252445220947, 0.6286118030548096, 0.6081708073616028, 0.6108120679855347, 0.6155912280082703, 0.6357510089874268, 0.663478434085846, 0.7127017378807068, 0.6087689995765686, 0.6709718704223633, 0.8169151544570923, 0.6787916421890259, 0.9910654425621033, 0.7740933299064636, 1.0768201351165771, 1.1622896194458008, 0.6241317987442017, 1.3442974090576172, 1.2392735481262207, 0.6929738521575928, 1.0748870372772217, 0.8535088300704956, 0.8760952949523926, 0.9260212779045105, 0.6965538263320923, 0.9164588451385498, 0.6713351607322693, 0.9749480485916138, 0.904427707195282, 0.7598711252212524, 0.8898929953575134, 0.6374689936637878, 0.8968610763549805, 0.7124484777450562, 0.8701433539390564, 0.8774587512016296, 0.6351351737976074, 0.84571719 ...

# %%
predictions = sgir.predict(list(test['SMILES']))

plt.plot(predictions['prediction'], test['Cc '], 'o')
plt.plot([-5, 5], [-5,5], 'r')
plt.xlabel('Predicted values of Cc')
plt.ylabel('True values of Cc')
plt.xlim(-5, 5)
plt.ylim(-5, 5)

print('RMSE of predictor for test set is {}'.format(root_mean_squared_error(predictions['prediction'], test['Cc '])))
print('R2 value of predictor for test set is {}'.format(r2_score(predictions['prediction'], test['Cc '])))
print('MAE value for test set is {}'.format(mean_absolute_error(predictions['prediction'], test['Cc '])))
# Out:
# RMSE of predictor for test set is 0.7037279683003838
# R2 value of predictor for test set is 0.25712398584323615
# MAE value for test set is 0.5592979866266251

# %%
def manual_cross_val_predict(cv, X, y, estimator, unlbl, random_state = 0, shuffle = True):
    X = X.reset_index(drop = True)
    y = y.reset_index(drop = True)
    y_pred = np.empty_like(y)
    kfold = KFold(n_splits=cv, shuffle = True, random_state = random_state)
    for train_idx, test_idx in kfold.split(X, y):
        model = estimator
        X_train = X[train_idx]
        y_train = y[train_idx]
        X_test = X[test_idx]
        y_test = y[test_idx]
        
        model.fit(X_train = list(X_train), y_train = list(y_train), X_unlbl = list(unlbl['SMILES']))
        y_pred[test_idx] = model.predict(list(X_test))['prediction'].squeeze()
    return y_pred

# %%
cross_val_predictions = manual_cross_val_predict(cv = 5, X = train['SMILES'], y = train['Cc '], 
                                                 estimator = SGIRMolecularPredictor(gnn_type='gcn', graph_pooling='max', hidden_size=218, num_layer=3, use_lr_scheduler=False, weight_decay=0.0002076634657605131),
                                                 unlbl = unlbl)
# Out:
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(

# %%
print('RMSE for CV is {}'.format(root_mean_squared_error(cross_val_predictions, train['Cc '])))
print('R2 value for for CV is {}'.format(r2_score(cross_val_predictions, train['Cc '])))
print('MAE value for CV is {}'.format(mean_absolute_error(cross_val_predictions, train['Cc '])))
# Out:
# RMSE for CV is 1.1541357446985174
# R2 value for for CV is -0.5459882255442468
# MAE value for CV is 0.7255350066726668
