# %% [markdown]
# **Overview**
# This notebook describes Cc prediction with torch-molecule models. There are 9 DL models for properties predction (mostly, different types of GNNs). The structure of notebook resembles the one, employing shallow methods. First, we assess model performance and select the best one

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

from torch_molecule import GREAMolecularPredictor
from tqdm import tqdm

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score, cross_val_predict
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score, root_mean_squared_error, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from hyperopt import tpe, Trials, hp, fmin, STATUS_OK
from functools import partial
from sklearn.neighbors import KNeighborsRegressor

# %%
from torch_molecule import GREAMolecularPredictor, BFGNNMolecularPredictor, SGIRMolecularPredictor, GRINMolecularPredictor, DIRMolecularPredictor, SSRMolecularPredictor, IRMMolecularPredictor, RPGNNMolecularPredictor, GNNMolecularPredictor, LSTMMolecularPredictor

# %% [markdown]
# We import dataset, containing Cc values vs SMILES of molecules

# %%
data_non_ionic = pd.read_csv('Data_non_ionic.csv', usecols=[1,2])

# %%
def calculate_to_score(estimator, dataset):
    train, test = train_test_split(dataset, random_state=0, train_size=0.75)
    train, val = train_test_split(train, random_state=0, train_size=0.12)
    
    est = estimator
    best_estimator  = est.autofit(X_train = list(train['SMILES']),
                                        y_train = list(train['Cc ']),
                                        X_val = list(val['SMILES']),
                                        y_val = list(val['Cc ']), n_trials = 10)    
    
    predictions= best_estimator.predict(list(test['SMILES']))['prediction']
    predictions_train = best_estimator.predict(list(train['SMILES']))['prediction']
    scores['Estimator'].append(est.model_name)
    scores['R2_test'].append(r2_score(test['Cc '], predictions))
    scores['R2_train'].append(r2_score(train['Cc '], predictions_train))
        
    scores['RMSE_test'].append(root_mean_squared_error(test['Cc '], predictions))
    scores['RMSE_train'].append(root_mean_squared_error(train['Cc '], predictions_train))

        
    scores['MAE_test'].append(mean_absolute_error(test['Cc '], predictions))
    scores['MAE_train'].append(mean_absolute_error(train['Cc '], predictions_train))

# %%
scores = { 'Estimator': [],  'R2_test':[], 'RMSE_test':[], 'MAE_test':[], 'R2_train':[], 'RMSE_train':[], 'MAE_train':[] }
trained_models = {}

# %% [markdown]
# Let's initialize scores dictionary and test function with Logistic Regression

# %%
models = [GREAMolecularPredictor, BFGNNMolecularPredictor, GRINMolecularPredictor, DIRMolecularPredictor, SSRMolecularPredictor, IRMMolecularPredictor, RPGNNMolecularPredictor,GNNMolecularPredictor]

# %%
for model in tqdm(models):
    calculate_to_score(model(device = 'cuda:0'), dataset = data_non_ionic)
# Out:
# 100%|██████████| 8/8 [1:43:33<00:00, 776.69s/it]

# %%
pd.DataFrame(scores)
# Out:
#                  Estimator   R2_test  RMSE_test  MAE_test  R2_train  \
# 0   GREAMolecularPredictor -0.105418   1.962004  1.321146  0.972535
# 1  BFGNNMolecularPredictor -1.183498   2.757484  1.465650  0.969040
# 2   GRINMolecularPredictor -0.723454   2.449832  1.684017  0.770503
# 3    DIRMolecularPredictor -0.277481   2.109181  1.536233  0.440535
# 4    SSRMolecularPredictor -0.661685   2.405530  1.311938  0.782461
# 5    IRMMolecularPredictor -1.035030   2.662085  1.823799  0.677472
# 6  RPGNNMolecularPredictor -0.280865   2.111973  1.463936  0.919851
# 7    GNNMolecularPredictor -0.122486   1.977093  1.389477  0.903009
#
#    RMSE_train  MAE_train
# 0    0.432490   0.343741
# 1    0.459186   0.316376
# 2    1.250191   0.998332
# 3    1.951977   1.515149
# 4    1.217185   0.838305
# 5    1.482082   1.176703
# 6    0.738816   0.484820
# 7    0.812743   0.572637

# %% [markdown]
# Two models:
# 1. SGIRMolecular predictor
# 2. LSTMMolecular predictor
#
# Must be done and loaded to scores manually. First we start with SGIRMolecular predictor, which requires the use of unlabelled SMILES

# %%
sgir = SGIRMolecularPredictor()
train, test = train_test_split(data_non_ionic, random_state=0, train_size=0.75)
val, unlb = train_test_split(data_non_ionic, random_state=0, train_size=0.5)

# %%
sgir.autofit(X_train = list(train['SMILES']),y_train = list(train['Cc ']),
             X_val = list(val['SMILES']),y_val  =list(val['Cc ']), X_unlbl = list(unlb['SMILES']))
# Out:
# SGIRMolecularPredictor(device=device(type='cuda', index=0), model_name='SGIRMolecularPredictor', model_class=<class 'torch_molecule.predictor.grea.model.GREA'>, model=GREA(
#   (graph_encoder): GNN_node(
#     (atom_encoder): AtomEncoder(
#       (atom_embedding_list): ModuleList(
#         (0): Embedding(120, 94, max_norm=1)
#         (1): Embedding(5, 94, max_norm=1)
#         (2-3): 2 x Embedding(12, 94, max_norm=1)
#         (4): Embedding(10, 94, max_norm=1)
#         (5-6): 2 x Embedding(6, 94, max_norm=1)
#         (7-8): 2 x Embedding(2, 94, max_norm=1)
#       )
#     )
#     (bond_encoder): BondEncoder(
#       (bond_embedding_list): ModuleList(
#         (0): Embedding(5, 94, max_norm=1)
#         (1): Embedding(6, 94, max_norm=1)
#         (2): Embedding(2, 94, max_norm=1)
#       )
#     )
#     (convs): ModuleList(
#       (0-7): 8 x GINConv()
#     )
#     (batch_norms): ModuleList(
#       (0-7): 8 x GraphSizeNorm()
#     )
#   )
#   (separator): Separator(
#     (rationale_encoder): GNN_node(
#       (atom_encoder): AtomEncoder(
#         (atom_embedding_list): ModuleList(
#           (0): Embedding(120, 94, max_norm=1)
#           (1): Embedding(5, 94, max_norm=1)
#           (2-3): 2 x Embedding(12, 94, max_norm=1)
#           (4): Embedding(10, 94, max_norm=1)
#           (5-6): 2 x Embedding(6, 94, max_norm=1)
#           (7-8): 2 x Embedding(2, 94, max_norm=1)
#         )
#       )
#       (bond_encoder): BondEncoder(
#         (bond_embedding_list): ModuleList(
#           (0): Embedding(5, 94, max_norm=1)
#           (1): Embedding(6, 94, max_norm=1)
#           (2): Embedding(2, 94, max_norm=1)
#         )
#       )
#       (convs): ModuleList(
#         (0-1): 2 x GINConv()
#       )
#       (batch_norms): ModuleList(
#         (0-1): 2 x BatchNorm1d(94, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (gate_nn): Sequential(
#       (0): Linear(in_features=94, out_features=188, bias=True)
#       (1): BatchNorm1d(188, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.5, inplace=False)
#       (4): Linear(in_features=188, out_features=1, bias=True)
#     )
#   )
#   (predictor): MLP(
#     (fc1): Linear(in_features=1285, out_features=188, bias=True)
#     (bn1): BatchNorm1d(188, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act
782470703, 1.2557542324066162, 1.2396328449249268, 1.2361338138580322, 1.2322874069213867, 1.282997965812683, 1.376663327217102, 1.3004961013793945, 1.2486793994903564, 1.2274937629699707, 1.2209969758987427, 1.21327543258667, 1.2087056636810303, 1.2551876306533813, 1.3939142227172852, 1.2697192430496216, 1.2097055912017822, 1.2077531814575195, 1.3083159923553467, 1.3181947469711304, 1.2272106409072876, 1.2065311670303345, 1.340941071510315, 1.3119295835494995, 1.2213871479034424, 1.2697820663452148, 1.3686596155166626, 1.2466787099838257, 1.3319250345230103, 1.2453844547271729, 1.165705680847168, 1.2384936809539795, 1.2706551551818848, 1.2073312997817993, 1.1676478385925293, 1.16516125202178 ...

# %%
predictions= sgir.predict(list(test['SMILES']))['prediction']
predictions_train = sgir.predict(list(train['SMILES']))['prediction']

scores['Estimator'].append(sgir.model_name)
scores['R2_test'].append(r2_score(test['Cc '], predictions))
scores['R2_train'].append(r2_score(train['Cc '], predictions_train))
        
scores['RMSE_test'].append(root_mean_squared_error(test['Cc '], predictions))
scores['RMSE_train'].append(root_mean_squared_error(train['Cc '], predictions_train))

        
scores['MAE_test'].append(mean_absolute_error(test['Cc '], predictions))
scores['MAE_train'].append(mean_absolute_error(train['Cc '], predictions_train))

# %% [markdown]
# Then we perform the same operations with LSTM predictor, which requires the use of target inout as Numpy array, not list

# %%
train, test = train_test_split(data_non_ionic, random_state=0, train_size=0.75)
val, test = train_test_split(test, random_state=0, train_size=0.5)

# %%
lstm = LSTMMolecularPredictor()

# %%
lstm.autofit(X_train = list(train['SMILES']),
             y_train = np.array(train['Cc ']),
             X_val = list(val['SMILES']),
             y_val = np.array(val['Cc ']))
# Out:
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# ...
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([57])) that is different to the input size (torch.Size([57, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# LSTMMolecularPredictor(device=device(type='cuda', index=0), model_name='LSTMMolecularPredictor', model_class=<class 'torch_molecule.predictor.lstm.model.LSTM'>, model=LSTM(
#   (embedding): Embedding(54, 21)
#   (lstm1): LSTM(21, 86, batch_first=True, bidirectional=True)
#   (lstm2): LSTM(172, 86, batch_first=True, bidirectional=True)
#   (timedist_dense): Linear(in_features=172, out_features=43, bias=True)
#   (relu): ReLU()
#   (fc): Linear(in_features=8600, out_features=1, bias=True)
# ), is_fitted_=True, num_task=1, task_type='regression', input_dim=54, output_dim=21, LSTMunits=86, max_input_len=200, batch_size=128, epochs=500, loss_criterion=MSELoss(), evaluate_criterion=<function mean_absolute_error at 0x00000255D6942480>, evaluate_higher_better=False, learning_rate=0.009094020113564808, weight_decay=7.008065391680066e-08, patience=50, use_lr_scheduler=False, scheduler_factor=0.23345074302472835, scheduler_patience=5, verbose=False, fitting_loss=[6.076171875, 89.9295654296875, 6.309564113616943, 6.307021617889404, 9.276055335998535, 6.361172199249268, 6.116414546966553, 6.074392795562744, 6.0796613693237305, 6.083321571350098, 6.0936198234558105, 6.077254295349121, 6.082727432250977, 6.083963394165039, 6.074512004852295, 6.07524299621582, 6.074638366699219, 6.07521915435791, 6.074485778808594, 6.0753655433654785, 6.0745649337768555, 6.074855804443359, 6.075357437133789, 6.074626922607422, 6.074576377868652, 6.075272083282471, 6.075473785400391, 6.074965953826904, 6.074516773223877, 6.074472427368164, 6.074769973754883, 6.075422286987305, 6.076621055603027, 6.0789055824279785, 6.081509113311768, 6.081631183624268, 6.076691150665283, 6.074525356292725, 6.077451229095459, 6.078688621520996, 6.0757575035095215, 6.0746660232543945, 6.077017784118652, 6.076765060424805, 6.074533462524414, 6.07560920715332, 6.07650899887085, 6.074752330780029, 6.074986934661865, 6.075978755950928, 6.074793338775635, 6.074757099151611, 6.075559139251709, 6.074742317199707, 6.074662208557129, 6.075261116027832, 6.074676513671875, 6.07461404800415, 6.075048923492432, 6.07464075088501, 6.074571132659912, 6.074902534484863, 6.074618339538574], fitting_epoch=11)

# %%
predictions= lstm.predict(list(test['SMILES']))['prediction']
predictions_train = lstm.predict(list(train['SMILES']))['prediction']

scores['Estimator'].append(lstm.model_name)
scores['R2_test'].append(r2_score(test['Cc '], predictions))
scores['R2_train'].append(r2_score(train['Cc '], predictions_train))
        
scores['RMSE_test'].append(root_mean_squared_error(test['Cc '], predictions))
scores['RMSE_train'].append(root_mean_squared_error(train['Cc '], predictions_train))

        
scores['MAE_test'].append(mean_absolute_error(test['Cc '], predictions))
scores['MAE_train'].append(mean_absolute_error(train['Cc '], predictions_train))

# %%
pd.DataFrame(scores)
# Out:
#                  Estimator   R2_test  RMSE_test  MAE_test  R2_train  \
# 0   GREAMolecularPredictor -0.105418   1.962004  1.321146  0.972535
# 1  BFGNNMolecularPredictor -1.183498   2.757484  1.465650  0.969040
# 2   GRINMolecularPredictor -0.723454   2.449832  1.684017  0.770503
# 3    DIRMolecularPredictor -0.277481   2.109181  1.536233  0.440535
# 4    SSRMolecularPredictor -0.661685   2.405530  1.311938  0.782461
# 5    IRMMolecularPredictor -1.035030   2.662085  1.823799  0.677472
# 6  RPGNNMolecularPredictor -0.280865   2.111973  1.463936  0.919851
# 7    GNNMolecularPredictor -0.122486   1.977093  1.389477  0.903009
# 8   SGIRMolecularPredictor  0.796594   2.524374  1.229710  0.964259
# 9   LSTMMolecularPredictor -0.044157   7.615885  3.739675  0.003607
#
#    RMSE_train  MAE_train
# 0    0.432490   0.343741
# 1    0.459186   0.316376
# 2    1.250191   0.998332
# 3    1.951977   1.515149
# 4    1.217185   0.838305
# 5    1.482082   1.176703
# 6    0.738816   0.484820
# 7    0.812743   0.572637
# 8    0.465941   0.264838
# 9    2.460164   1.834284

# %%
with open('scores_non_ionic_torch.pickle', 'wb') as output:
    pickle.dump(scores, output)

# %% [markdown]
# As we can see, SGIR model have the best generalization performace (highest R2, lowest RMSE - about 0.36 lower, than for the best shallow model). We will perform hyperparameter tuning for SGIR using *hyperopt* package

# %%
def objective(params, X):
    SGIR = SGIRMolecularPredictor(num_layer = params['num_layer'], hidden_size = params['hidden_size'], gnn_type = params['gnn_type'], graph_pooling = params['graph_pooling'], weight_decay = params['weight_decay'], use_lr_scheduler = params['use_lr_scheduler'])
    kf = KFold(n_splits = 5)
    cv_rmse_results = []
    cv_mae_results = []
    cv_r2_results = []
    
    for train_unlb_indices, test_indices in kf.split(X):
        
        train_indices, unlbl_indices = train_test_split(train_unlb_indices, random_state = 0, train_size=0.8)
        
        X_train = X.iloc[train_indices, :]['SMILES']
        y_train = X.iloc[train_indices, :]['Cc ']
        X_unlbl  = X.iloc[unlbl_indices, :]['SMILES']

        

        X_test = X.iloc[test_indices, :]['SMILES']
        y_test = X.iloc[test_indices, :]['Cc ']
        
        sgir.fit(X_train = list(X_train), y_train = list(y_train), X_unlbl = list(X_unlbl))

        predictions = sgir.predict(list(X_test))['prediction']
        
        cv_rmse_results.append(root_mean_squared_error(y_test, predictions))
        cv_mae_results.append(mean_absolute_error(y_test, predictions))
        cv_r2_results.append(r2_score(y_test, predictions))

    return {'loss':np.mean(cv_rmse_results), 'status':STATUS_OK, 'model':sgir, 'r2':-np.mean(cv_r2_results), 'mae':-np.mean(cv_mae_results)}

# %%
trials = Trials()

# %%
param_grid = {'num_layer': hp.randint('num_layer', 3,7),
              'hidden_size':hp.randint('hidden_size', 200, 400),
              'gnn_type': hp.choice('gnn_type', ["gin-virtual", "gcn-virtual", "gin", "gcn"]),
              'graph_pooling':hp.choice('graph_pooling', ['mean', 'sum', 'max']),
              'weight_decay':hp.loguniform('weight_decay', -13, -4),
              'use_lr_scheduler':hp.choice('use_lr_scheduler', [True, False])}

# %%
best = fmin(partial(objective, X = data_non_ionic), space = param_grid, trials = trials, algo = tpe.suggest, max_evals=  25)
# Out:
#   0%|          | 0/25 [00:00<?, ?trial/s, best loss=?]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#   4%|▍         | 1/25 [04:01<1:36:28, 241.21s/trial, best loss: 2.3490402093832286]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#   8%|▊         | 2/25 [07:30<1:25:19, 222.59s/trial, best loss: 2.2355203922618263]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  12%|█▏        | 3/25 [11:12<1:21:26, 222.10s/trial, best loss: 2.2355203922618263]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  16%|█▌        | 4/25 [14:55<1:17:54, 222.59s/trial, best loss: 2.2355203922618263]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  20%|██        | 5/25 [18:22<1:12:20, 217.02s/trial, best loss: 2.2355203922618263]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  24%|██▍       | 6/25 [22:38<1:12:51, 230.07s/trial, best loss: 2.212599965392079]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  28%|██▊       | 7/25 [26:56<1:11:45, 239.19s/trial, best loss: 2.212599965392079]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  32%|███▏      | 8/25 [31:15<1:09:35, 245.62s/trial, best loss: 2.212599965392079]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  36%|███▌      | 9/25 [35:35<1:06:44, 250.26s/trial, best loss: 2.212599965392079]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  40%|████      | 10/25 [39:57<1:03:27, 253.86s/trial, best loss: 2.212599965392079]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  44%|████▍     | 11/25 [43:43<57:13, 245.27s/trial, best loss: 2.212599965392079]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  48%|████▊     | 12/25 [47:27<51:45, 238.86s/trial, best loss: 2.212599965392079]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  52%|█████▏    | 13/25 [51:12<46:54, 234.50s/trial, best loss: 2.212599965392079]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  56%|█████▌    | 14/25 [54:56<42:24, 231.28s/trial, best loss: 2.212599965392079]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  60%|██████    | 15/25 [58:24<37:22, 224.28s/trial, best loss: 2.212599965392079]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  64%|██████▍   | 16/25 [1:01:52<32:53, 219.30s/trial, best loss: 2.212599965392079]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  68%|██████▊   | 17/25 [1:05:35<29:25, 220.68s/trial, best loss: 2.212599965392079]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  72%|███████▏  | 18/25 [1:09:16<25:45, 220.79s/trial, best loss: 2.212599965392079]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  76%|███████▌  | 19/25 [1:12:58<22:05, 220.96s/trial, best loss: 2.212599965392079]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  80%|████████  | 20/25 [1:16:37<18:21, 220.34s/trial, best loss: 2.212599965392079]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  84%|████████▍ | 21/25 [1:20:25<14:51, 222.85s/trial, best loss: 2.212599965392079]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  88%|████████▊ | 22/25 [1:24:16<11:15, 225.14s/trial, best loss: 2.208280475308075]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  92%|█████████▏| 23/25 [1:27:52<07:25, 222.54s/trial, best loss: 2.208280475308075]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#  96%|█████████▌| 24/25 [1:32:17<03:55, 235.08s/trial, best loss: 2.208280475308075]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# 100%|██████████| 25/25 [1:36:10<00:00, 230.82s/trial, best loss: 2.208280475308075]

# %%
print(best)
# Out:
# {'gnn_type': 2, 'graph_pooling': 1, 'hidden_size': 345, 'num_layer': 6, 'use_lr_scheduler': 0, 'weight_decay': 3.256490380772579e-05}

# %% [markdown]
# Let's finally fit the best estimator and plot predicted values vs true ones

# %%
train, test = train_test_split(data_non_ionic, random_state=0)
train, unlbl = train_test_split(train, random_state=0, train_size=0.9)

# %%
sgir = SGIRMolecularPredictor(gnn_type='gin', graph_pooling='sum', hidden_size=345, num_layer=6, use_lr_scheduler=True, weight_decay=3.256490380772579e-05)
sgir.fit(X_train = list(train['SMILES']),
               y_train=list(train['Cc ']),
               X_unlbl = list(unlbl['SMILES']))
# Out:
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# SGIRMolecularPredictor(device=device(type='cuda', index=0), model_name='SGIRMolecularPredictor', model_class=<class 'torch_molecule.predictor.grea.model.GREA'>, model=GREA(
#   (graph_encoder): GNN_node(
#     (atom_encoder): AtomEncoder(
#       (atom_embedding_list): ModuleList(
#         (0): Embedding(120, 345, max_norm=1)
#         (1): Embedding(5, 345, max_norm=1)
#         (2-3): 2 x Embedding(12, 345, max_norm=1)
#         (4): Embedding(10, 345, max_norm=1)
#         (5-6): 2 x Embedding(6, 345, max_norm=1)
#         (7-8): 2 x Embedding(2, 345, max_norm=1)
#       )
#     )
#     (bond_encoder): BondEncoder(
#       (bond_embedding_list): ModuleList(
#         (0): Embedding(5, 345, max_norm=1)
#         (1): Embedding(6, 345, max_norm=1)
#         (2): Embedding(2, 345, max_norm=1)
#       )
#     )
#     (convs): ModuleList(
#       (0-5): 6 x GINConv()
#     )
#     (batch_norms): ModuleList(
#       (0-5): 6 x BatchNorm1d(345, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (separator): Separator(
#     (rationale_encoder): GNN_node(
#       (atom_encoder): AtomEncoder(
#         (atom_embedding_list): ModuleList(
#           (0): Embedding(120, 345, max_norm=1)
#           (1): Embedding(5, 345, max_norm=1)
#           (2-3): 2 x Embedding(12, 345, max_norm=1)
#           (4): Embedding(10, 345, max_norm=1)
#           (5-6): 2 x Embedding(6, 345, max_norm=1)
#           (7-8): 2 x Embedding(2, 345, max_norm=1)
#         )
#       )
#       (bond_encoder): BondEncoder(
#         (bond_embedding_list): ModuleList(
#           (0): Embedding(5, 345, max_norm=1)
#           (1): Embedding(6, 345, max_norm=1)
#           (2): Embedding(2, 345, max_norm=1)
#         )
#       )
#       (convs): ModuleList(
#         (0-1): 2 x GINConv()
#       )
#       (batch_norms): ModuleList(
#         (0-1): 2 x BatchNorm1d(345, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (gate_nn): Sequential(
#       (0): Linear(in_features=345, out_features=690, bias=True)
#       (1): BatchNorm1d(690, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.5, inplace=False)
#       (4): Linear(in_features=690, out_features=1, bias=True)
#     )
#   )
#   (predictor): MLP(
#     (fc1): Linear(in_features=1536, out_features=690, bias=True)
#     (bn1): BatchNorm1d(690, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act
153089046478271, 1.713644027709961, 1.715386152267456, 1.757957935333252, 1.7477390766143799, 1.7422454357147217, 1.7423304319381714, 1.7377501726150513, 1.6904966831207275, 1.6892706155776978, 1.6855071783065796, 1.6802786588668823, 1.676729679107666, 1.8453205823898315, 1.8450233936309814, 1.8445169925689697, 1.842599630355835, 1.8416244983673096, 1.7503752708435059, 1.7490230798721313, 1.747531533241272, 1.7458550930023193, 1.744295358657837, 1.6937615871429443, 1.6920984983444214, 1.6908135414123535, 1.6905157566070557, 1.6902660131454468, 1.6599711179733276, 1.6577956676483154, 1.6553186178207397, 1.6528339385986328, 1.6521916389465332, 1.754081130027771, 1.7508232593536377, 1.7481162548065186, 1.7459514141082764, 1.744360327720642, 1.7463613748550415, 1.7445207834243774, 1.7430405616760254, 1.742113471031189, 1.7419580221176147, 1.706309199333191, 1.7043395042419434, 1.7026745080947876, 1.7012923955917358, 1.7003579139709473, 1.7112 ...

# %%
predictions = sgir.predict(list(test['SMILES']))

plt.plot(predictions['prediction'], test['Cc '], 'o')
plt.plot([-5, 5], [-5,5], 'r')
plt.xlabel('Predicted values of Cc')
plt.ylabel('True values of Cc')
plt.xlim(-5, 5)
plt.ylim(-5, 5)

print('RMSE of predictor for test set is {}'.format(root_mean_squared_error(predictions['prediction'], test['Cc '])))
print('R2 value of predictor for test set is {}'.format(r2_score(predictions['prediction'], test['Cc '])))
print('MAE value for test set is {}'.format(mean_absolute_error(predictions['prediction'], test['Cc '])))
# Out:
# RMSE of predictor for test set is 1.4669486633042546
# R2 value of predictor for test set is 0.5401200596833701
# MAE value for test set is 1.1003697405865316

# %%
def manual_cross_val_predict(cv, X, y, estimator, unlbl, random_state = 0, shuffle = True):
    X = X.reset_index(drop = True)
    y = y.reset_index(drop = True)
    y_pred = np.empty_like(y)
    kfold = KFold(n_splits=cv, shuffle = True, random_state = random_state)
    for train_idx, test_idx in kfold.split(X, y):
        model = estimator
        X_train = X[train_idx]
        y_train = y[train_idx]
        X_test = X[test_idx]
        y_test = y[test_idx]
        
        model.fit(X_train = list(X_train), y_train = list(y_train), X_unlbl = list(unlbl['SMILES']))
        y_pred[test_idx] = model.predict(list(X_test))['prediction'].squeeze()
    return y_pred

# %%
cross_val_predictions = manual_cross_val_predict(cv = 5, X = train['SMILES'], y = train['Cc '], 
                                                 estimator = SGIRMolecularPredictor(gnn_type='gin', graph_pooling='sum', hidden_size=345, num_layer=6, use_lr_scheduler=True, weight_decay=3.256490380772579e-05),
                                                 unlbl = unlbl)
# Out:
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_molecule\predictor\sgir\modeling_sgir.py:121: UserWarning: No validation set provided. Using training set for validation.
#   warnings.warn(

# %%
print('RMSE for CV is {}'.format(root_mean_squared_error(cross_val_predictions, train['Cc '])))
print('R2 value for for CV is {}'.format(r2_score(cross_val_predictions, train['Cc '])))
print('MAE value for CV is {}'.format(mean_absolute_error(cross_val_predictions, train['Cc '])))
# Out:
# RMSE for CV is 1.7474211059214357
# R2 value for for CV is 0.1371441067178757
# MAE value for CV is 1.3008740984824747
