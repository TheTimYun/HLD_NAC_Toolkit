# %% [markdown]
# **Overview**
# This notebook describes folloiwing stages:
# 1. Creating functions to:
#     - perform search for optimal algorithm parameters;
#     - train model;
#     - calculate the most important metrics;
#     - plot ROC-AUC curve
# 2. Assess the results of following algorithms:
#     - Logistic regression;
#     - Random Forest;
#     - Gradient Boosting as implemented in XGBoost;
#     - Support Vector Machines;
#     - K-Nearest Neighborrs
# 3. Creare dataframe with the main indiators of models' performance

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score, cross_val_predict
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score, root_mean_squared_error, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from hyperopt import tpe, Trials, hp, fmin, STATUS_OK
from functools import partial
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# First, let's import datasets and y-target, created earlier:

# %%
with open ('padel_descks.pickle', 'rb') as inp:
    padel_descs = pickle.load(inp)

# %%
data_ionic = pd.read_csv('Data_ionic.csv')
target_ionic = data_ionic['Cc ']

data_extended = pd.read_csv('Data_extended.csv')
target_extended = data_extended['Cc ']

data_non_ionic = pd.read_csv('Data_non_ionic.csv')
target_non_ionic = data_non_ionic['Cc ']

targets = {'Padel_ionic': target_ionic, 'Padel_non_ionic': target_non_ionic, 'Padel_extended':target_extended}

# %%
scores_ionic = {'Descriptors':[], 'Estimator': [], 'R2_cv':[], 'MAE_cv':[], 'RMSE_cv':[],
          'R2_test':[], 'RMSE_test':[], 'MAE_test':[], 'R2_train':[], 'RMSE_train':[], 'MAE_train':[] }

scores_non_ionic = {'Descriptors':[], 'Estimator': [], 'R2_cv':[], 'MAE_cv':[], 'RMSE_cv':[],
          'R2_test':[], 'RMSE_test':[], 'MAE_test':[], 'R2_train':[], 'RMSE_train':[], 'MAE_train':[] }

scores_extended = {'Descriptors':[], 'Estimator': [], 'R2_cv':[], 'MAE_cv':[], 'RMSE_cv':[],
          'R2_test':[], 'RMSE_test':[], 'MAE_test':[], 'R2_train':[], 'RMSE_train':[], 'MAE_train':[] }

scores = {'Padel_ionic': scores_ionic, 'Padel_non_ionic': scores_non_ionic, 'Padel_extended':scores_extended}

# %%
def get_best_model_from_trials(trials):
    valid_trial_list = [trial for trial in trials if trial['result']['status'] == STATUS_OK]
    losses = [ float(trial['result']['loss']) for trial in valid_trial_list]
    index_having_minumum_loss = np.argmin(losses)
    best_trial_obj = valid_trial_list[index_having_minumum_loss]
    return best_trial_obj['result']

# %%
def calculate_to_score(estimator, estimator_name, param_grid, descriptors_dict = padel_descs, targets = targets, n_iters = 150):
    fig, axes = plt.subplots(1, 3, figsize = (12,8))
    i = 0
    
    for key, value in descriptors_dict.items():
        target = targets[key]
        X_train, X_test, y_train, y_test = train_test_split(value, target, random_state = 0)
        def objective(params, X, target):
            pipe = make_pipeline(StandardScaler(), estimator)
            pipe.set_params(**params)
            y_cv_pred = cross_val_predict(pipe, X, target, cv=5)
            cv_rmse = np.sqrt(root_mean_squared_error(target, y_cv_pred))
            cv_r2 = r2_score(target, y_cv_pred)
            
            score = cross_val_score(pipe, X, target, cv = 10, scoring = 'neg_mean_absolute_error')
            return {'loss':-score.mean(), 'status':STATUS_OK, 'Trained_model':pipe, 'rmse':cv_rmse, 'r2':cv_r2}
        
        trials = Trials()
        best = fmin(partial(objective, X = X_train, target = y_train), space = param_grid, trials = trials, algo = tpe.suggest, max_evals=  n_iters)
        print(best)
        
        best_estimator  = get_best_model_from_trials(trials)['Trained_model']
      
        
        cv_r2 = get_best_model_from_trials(trials)['r2']
        cv_rmse = get_best_model_from_trials(trials)['rmse']
        cv_mae = get_best_model_from_trials(trials)['loss']
        
        scores[key]['Descriptors'].append('Padel')
        scores[key]['R2_cv'].append(cv_r2)
        scores[key]['RMSE_cv'].append(cv_rmse)
        scores[key]['MAE_cv'].append(cv_mae)
        
        best_estimator.fit(X_train, y_train)
        predictions = best_estimator.predict(X_test)
        predictions_train = best_estimator.predict(X_train)
        scores[key]['Estimator'].append(estimator_name)
        scores[key]['R2_test'].append(r2_score(y_test, predictions))
        scores[key]['R2_train'].append(r2_score(y_train, predictions_train))
        
        scores[key]['RMSE_test'].append(root_mean_squared_error(y_test, predictions))
        scores[key]['RMSE_train'].append(root_mean_squared_error(y_train, predictions_train))

        
        scores[key]['MAE_test'].append(mean_absolute_error(y_test, predictions))
        scores[key]['MAE_train'].append(mean_absolute_error(y_train, predictions_train))
        
        axes[i].plot(y_test, predictions, 'ro', label = 'Test values')
        axes[i].plot(y_train, predictions_train, 'go', label = 'Train values')
        axes[i].plot([target.min(),target.max()], [target.min(),target.max()])
        axes[i].set_title('True vs predicted values for {} descriptors'.format(key))
        axes[i].set_xlabel('True test values')
        axes[i].set_ylabel('Predicted test values')
        axes[i].legend()
        i += 1
    plt.tight_layout()
    plt.savefig('All_classes_Padel_{}_scattter.png'.format(estimator_name))

# %% [markdown]
# Subfunction below is to retrieve best model from Trials object ans is used in main functions

# %% [markdown]
# Let's initialize scores dictionary and test function with Logistic Regression

# %%
calculate_to_score(Ridge(max_iter = 10000), estimator_name='Linear Regression', 
                   param_grid = {'ridge__alpha':hp.loguniform(label = 'alpha', low = -4*np.log(10), high  = 2*np.log(10)),
                                'ridge__solver':hp.choice(label = 'solver', options = ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg','sag', 'saga'])})
# Out:
# 100%|██████████████████████████████████████████████| 150/150 [07:41<00:00,  3.08s/trial, best loss: 1.6384096031884123]
# {'alpha': 0.563252343915379, 'solver': 5}
# 100%|███████████████████████████████████████████████| 150/150 [04:50<00:00,  1.94s/trial, best loss: 8.471663221531774]
# {'alpha': 99.58582460213258, 'solver': 2}
# 100%|██████████████████████████████████████████████| 150/150 [00:53<00:00,  2.81trial/s, best loss: 0.7725383177535099]
# {'alpha': 13.235597135520521, 'solver': 1}

# %% [markdown]
# Let's continue with other models. The first one will be
# **Random Forest Classification**

# %%
space = {
    'randomforestregressor__max_depth': hp.randint('max_depth', 3, 15),  
    'randomforestregressor__max_features': hp.choice('max_features', [0.3, 0.5, 'sqrt', 'log2']), 
    'randomforestregressor__min_samples_split': hp.randint('min_samples_split', 5, 20),  
    'randomforestregressor__min_samples_leaf': hp.randint('min_samples_leaf', 3, 10), 
    'randomforestregressor__criterion': hp.choice('criterion', ["squared_error", "absolute_error"]), 
    'randomforestregressor__ccp_alpha': hp.uniform('ccp_alpha', 0, 0.1),  
    'randomforestregressor__n_estimators': hp.randint('n_estimators', 50, 200),  
    'randomforestregressor__bootstrap': hp.choice('bootstrap', [True]),  
    'randomforestregressor__max_samples': hp.uniform('max_samples', 0.6, 0.95)}

# %%
calculate_to_score(RandomForestRegressor(random_state = 0, n_jobs=-1), estimator_name = 'Random Forest', param_grid =  space)
# Out:
# 100%|██████████████████████████████████████████████| 150/150 [06:14<00:00,  2.50s/trial, best loss: 1.6504147441106203]
# {'bootstrap': 0, 'ccp_alpha': 0.06553440275026576, 'criterion': 0, 'max_depth': 6, 'max_features': 1, 'max_samples': 0.7375384644284306, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 157}
# 100%|███████████████████████████████████████████████| 150/150 [06:15<00:00,  2.51s/trial, best loss: 1.242674531370604]
# {'bootstrap': 0, 'ccp_alpha': 0.03240930261926479, 'criterion': 0, 'max_depth': 11, 'max_features': 2, 'max_samples': 0.9337049958002156, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 115}
# 100%|██████████████████████████████████████████████| 150/150 [06:11<00:00,  2.47s/trial, best loss: 0.7930645691609974]
# {'bootstrap': 0, 'ccp_alpha': 0.06742129097273669, 'criterion': 1, 'max_depth': 9, 'max_features': 0, 'max_samples': 0.8024709949897603, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 98}

# %% [markdown]
# **LightGBM**

# %%
space = {'lgbmregressor__max_depth':hp.randint('max_depth', 3, 12),
        'lgbmregressor__boosting_type':hp.choice('boosting_type', ['gbdt']),
        'lgbmregressor__reg_alpha':hp.loguniform('reg_alpha', -3*np.log(10), 1*np.log(10)),
         'lgbmregressor__reg_lamdba':hp.loguniform('reg_lambda', -3*np.log(10), 1*np.log(10)),
        'lgbmregressor__learning_rate':hp.loguniform('learning_rate', -3*np.log(10), 1*np.log(10)),
        'lgbmregressor__n_estimators':hp.randint('n_estimators', 50, 300),
        'lgbmregressor__n_leaves':hp.randint('n_leaves', 10, 50),
        'lgbmregressor__min_child_samples': hp.randint('min_child_samples', 5, 30)}

# %%
calculate_to_score(LGBMRegressor(verbosity = -1), estimator_name='Gradient boosting', param_grid = space)
# Out:
# 100%|██████████████████████████████████████████████| 150/150 [01:30<00:00,  1.66trial/s, best loss: 1.5868066315471798]
# {'boosting_type': 0, 'learning_rate': 0.012446047262543707, 'max_depth': 11, 'min_child_samples': 8, 'n_estimators': 234, 'n_leaves': 28, 'reg_alpha': 0.002195580130593997, 'reg_lambda': 0.04438209427414881}
# 100%|██████████████████████████████████████████████| 150/150 [01:25<00:00,  1.76trial/s, best loss: 1.0587815814976367]
# {'boosting_type': 0, 'learning_rate': 0.36220244109117344, 'max_depth': 8, 'min_child_samples': 16, 'n_estimators': 88, 'n_leaves': 24, 'reg_alpha': 0.05267794705769833, 'reg_lambda': 0.2307645177502705}
# 100%|██████████████████████████████████████████████| 150/150 [00:52<00:00,  2.86trial/s, best loss: 0.8108169154538981]
# {'boosting_type': 0, 'learning_rate': 0.01874214315031354, 'max_depth': 10, 'min_child_samples': 9, 'n_estimators': 107, 'n_leaves': 49, 'reg_alpha': 0.01657679956421881, 'reg_lambda': 9.026588191115092}

# %% [markdown]
# **SVM**

# %%
space = {'svr__C':hp.loguniform('C', -2*np.log(10), 1*np.log(10)),
         'svr__kernel':hp.choice('kernel', ['rbf','poly','linear', 'sigmoid']),
         'svr__degree':hp.choice('degree', [2,3,4]),
         'svr__gamma':hp.choice('gamma', ['scale', 'auto']),
         'svr__coef0':hp.loguniform('coef0', -1, 1)}

# %%
calculate_to_score(SVR(max_iter = 15000), estimator_name = 'SVR', param_grid = space, n_iters = 500)
# Out:
# 100%|███████████████████████████████████████████████| 500/500 [01:37<00:00,  5.11trial/s, best loss: 1.407504937857432]
# {'C': 4.071946102201005, 'coef0': 2.002373697250869, 'degree': 2, 'gamma': 0, 'kernel': 1}
#  12%|█████▌                                         | 59/500 [00:11<01:39,  4.43trial/s, best loss: 1.1924574184554406]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  22%|██████████▎                                    | 110/500 [00:22<01:25,  4.59trial/s, best loss: 1.192331586417517]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  23%|██████████▉                                    | 117/500 [00:23<01:22,  4.62trial/s, best loss: 1.192331586417517]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  29%|█████████████▋                                 | 145/500 [00:29<01:16,  4.63trial/s, best loss: 1.192331586417517]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  39%|██████████████████                            | 197/500 [00:40<01:08,  4.45trial/s, best loss: 1.1922833853820378]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  41%|██████████████████▊                           | 205/500 [00:41<01:06,  4.46trial/s, best loss: 1.1922833853820378]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  43%|███████████████████▋                          | 214/500 [00:43<01:02,  4.56trial/s, best loss: 1.1922833853820378]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  45%|████████████████████▌                         | 223/500 [00:45<01:00,  4.57trial/s, best loss: 1.1922833853820378]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  51%|███████████████████████▍                      | 255/500 [00:52<00:52,  4.63trial/s, best loss: 1.1922833853820378]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  56%|█████████████████████████▊                    | 280/500 [00:57<00:49,  4.43trial/s, best loss: 1.1922833853820378]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  58%|██████████████████████████▌                   | 289/500 [00:59<00:49,  4.29trial/s, best loss: 1.1922833853820378]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  60%|███████████████████████████▍                  | 298/500 [01:00<00:44,  4.59trial/s, best loss: 1.1922833853820378]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  62%|████████████████████████████▍                 | 309/500 [01:03<00:41,  4.58trial/s, best loss: 1.1922833853820378]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  63%|█████████████████████████████▏                | 317/500 [01:04<00:39,  4.58trial/s, best loss: 1.1922833853820378]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  65%|█████████████████████████████▉                | 326/500 [01:06<00:37,  4.59trial/s, best loss: 1.1922833853820378]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  76%|██████████████████████████████████▊           | 379/500 [01:17<00:27,  4.39trial/s, best loss: 1.1922424585191462]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  78%|███████████████████████████████████▊          | 389/500 [01:19<00:25,  4.41trial/s, best loss: 1.1922424585191462]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  80%|████████████████████████████████████▌         | 398/500 [01:21<00:23,  4.37trial/s, best loss: 1.1922424585191462]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  86%|███████████████████████████████████████▋      | 431/500 [01:28<00:15,  4.40trial/s, best loss: 1.1922424585191462]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  88%|████████████████████████████████████████▍     | 440/500 [01:30<00:13,  4.33trial/s, best loss: 1.1922424585191462]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  90%|█████████████████████████████████████████▌    | 452/500 [01:32<00:10,  4.37trial/s, best loss: 1.1922424585191462]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  98%|█████████████████████████████████████████████▎| 492/500 [01:41<00:01,  4.37trial/s, best loss: 1.1922424585191462]
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=15000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# 100%|██████████████████████████████████████████████| 500/500 [01:42<00:00,  4.86trial/s, best loss: 1.1922424585191462]
# {'C': 9.996506546744973, 'coef0': 1.350224389978347, 'degree': 1, 'gamma': 1, 'kernel': 0}
# 100%|██████████████████████████████████████████████| 500/500 [01:33<00:00,  5.36trial/s, best loss: 0.7346299986909759]
# {'C': 0.039600116548747566, 'coef0': 0.41920529465311074, 'degree': 2, 'gamma': 0, 'kernel': 2}

# %% [markdown]
# **KNearestneighbors**

# %%
space = {
    'kneighborsregressor__n_neighbors': hp.randint('n_neighbors', 3, 16),  # Увеличил диапазон
    'kneighborsregressor__weights': hp.choice('weights', ['uniform', 'distance']),
    'kneighborsregressor__metric': hp.choice('metric', ['minkowski', 'euclidean', 'manhattan']),  # Упростил выбор
    'kneighborsregressor__p': hp.uniform('p', 1, 3),  # Параметр для minkowski
    'kneighborsregressor__algorithm': hp.choice('algorithm', ['auto', 'ball_tree', 'kd_tree']),
    'kneighborsregressor__leaf_size': hp.randint('leaf_size', 10, 50)  # Для tree-based алгоритмов
}

# %%
calculate_to_score(KNeighborsRegressor(), estimator_name='KMeans', param_grid=space)
# Out:
# 100%|██████████████████████████████████████████████| 150/150 [00:30<00:00,  4.99trial/s, best loss: 1.5689545247736294]
# {'algorithm': 1, 'leaf_size': 39, 'metric': 0, 'n_neighbors': 5, 'p': 1.5495028356003777, 'weights': 1}
# 100%|██████████████████████████████████████████████| 150/150 [00:29<00:00,  5.11trial/s, best loss: 1.3933916263054296]
# {'algorithm': 2, 'leaf_size': 31, 'metric': 2, 'n_neighbors': 8, 'p': 2.887531805667086, 'weights': 1}
# 100%|██████████████████████████████████████████████| 150/150 [00:27<00:00,  5.36trial/s, best loss: 0.7459733647297202]
# {'algorithm': 2, 'leaf_size': 47, 'metric': 0, 'n_neighbors': 3, 'p': 1.266658042059948, 'weights': 1}

# %% [markdown]
# Let's save results into pickle file and show the final scores model in readable format

# %%
with open('scores_padel_descs.pickle', 'wb') as output:
    pickle.dump(scores, output)

# %%
with open('scores_padel_descs.pickle', 'rb') as inp:
    scores = pickle.load(inp)

# %%
pd.DataFrame(scores_ionic)
# Out:
#   Descriptors          Estimator     R2_cv    MAE_cv   RMSE_cv   R2_test  \
# 0       Padel  Linear Regression -0.842288  1.649285  2.118846 -0.735524
# 1       Padel  Linear Regression -0.832685  1.638410  2.116080 -1.210779
# 2       Padel      Random Forest -0.095556  1.650415  1.860667  0.013578
# 3       Padel  Gradient boosting -0.044226  1.586807  1.838479 -0.074359
# 4       Padel                SVR -0.439204  1.407505  1.992006 -0.309955
# 5       Padel             KMeans -0.015982  1.568955  1.825919 -0.562358
#
#    RMSE_test  MAE_test  R2_train  RMSE_train  MAE_train
# 0   2.784499  1.945702  0.996593    0.193053   0.143401
# 1   3.142711  2.184472  0.999159    0.095896   0.062746
# 2   2.099246  1.495659  0.476188    2.393911   1.096452
# 3   2.190819  1.717067  0.155487    3.039648   1.810044
# 4   2.419134  1.556386  0.998015    0.147365   0.108624
# 5   2.641934  1.837721  1.000000    0.000000   0.000000

# %%
pd.DataFrame(scores_non_ionic)
# Out:
#   Descriptors          Estimator       R2_cv    MAE_cv   RMSE_cv   R2_test  \
# 0       Padel  Linear Regression -498.901948  9.320175  7.423276  0.463684
# 1       Padel  Linear Regression -413.566457  8.471663  7.083908  0.527824
# 2       Padel      Random Forest    0.438246  1.242675  1.359130  0.225031
# 3       Padel  Gradient boosting    0.562300  1.058782  1.276934  0.290336
# 4       Padel                SVR    0.537436  1.192242  1.294695  0.219551
# 5       Padel             KMeans    0.394629  1.393392  1.384777  0.224170
#
#    RMSE_test  MAE_test  R2_train  RMSE_train  MAE_train
# 0   4.099037  2.461374  0.999937    0.019486   0.011538
# 1   3.846127  1.695319  0.929012    0.656659   0.466416
# 2   4.927353  2.071773  0.775074    1.168877   0.797957
# 3   4.715175  1.882289  0.998581    0.092856   0.068406
# 4   4.944745  1.798916  0.941705    0.595065   0.246800
# 5   4.930091  2.086340  1.000000    0.000000   0.000000

# %%
pd.DataFrame(scores_extended)
# Out:
#   Descriptors          Estimator     R2_cv    MAE_cv   RMSE_cv   R2_test  \
# 0       Padel  Linear Regression -1.110801  1.348783  1.226895 -0.215738
# 1       Padel  Linear Regression  0.307118  0.772538  0.928667  0.398623
# 2       Padel      Random Forest  0.030683  0.793065  1.009978  0.308109
# 3       Padel  Gradient boosting -0.074451  0.810817  1.036316 -0.003201
# 4       Padel                SVR  0.071211  0.734630  0.999251  0.415566
# 5       Padel             KMeans  0.149991  0.745973  0.977353 -0.019096
#
#    RMSE_test  MAE_test      R2_train  RMSE_train  MAE_train
# 0   1.485638  1.108072  1.000000e+00    0.000024   0.000015
# 1   1.044880  0.907824  7.865468e-01    0.478677   0.315745
# 2   1.120758  0.923615  5.172816e-01    0.719843   0.509858
# 3   1.349544  1.179292 -2.220446e-16    1.036074   0.848636
# 4   1.030056  0.927855  6.345139e-01    0.626363   0.282448
# 5   1.360193  1.096790  1.000000e+00    0.000000   0.000000
